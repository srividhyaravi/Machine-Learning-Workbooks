# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src = "https://ibm.box.com/shared/static/wbqvbi6o6ip0vz55ua5gp17g4f1k7ve9.png" width = 300, align = "center"></a>
# # <center>Random Forests</center>

# %% [markdown]
# <img src = "https://ibm.box.com/shared/static/860wrw1jvullt57vl470fe7zikucwzzh.png", height = 400, width = 400, align = 'right'>
# <img src = "https://ibm.box.com/shared/static/f7wewzfjxozemzlhsf7tay1me0alyofa.png", height = 150, width = 150, align = 'left'>

# %% [markdown]
# ### <b>Welcome to Lab 2c of Machine Learning with Python.</b>
# <p> <b>Machine Learning is a form of artificial intelligence (AI), where the system can "learn" without explicitly being coded</b></p>
#
# In this lab exercise, you will learn some popular machine learning algorithms. For <b>supervised learning</b>, we will discuss <b>decision trees</b> and <b>random forests</b>. In <b>unsupervised learning</b>, we will discuss <b>k-means clustering</b>, <b>agglomerative hierarchical clustering</b>, and <b>density-based clustering</b> or <b>DBSCAN</b>.

# %% [markdown]
# ### Some Notebook Commands Reminders:
# <ul>
#     <li>Run a cell: CTRL + ENTER</li>
#     <li>Create a cell above a cell: a</li>
#     <li>Create a cell below a cell: b</li>
#     <li>Change a cell to Markdown: m</li>
#
#     <li>Change a cell to code: y</li>
# </ul>
#
# <b> If you are interested in more keyboard shortcuts, go to Help -> Keyboard Shortcuts </b>

# %% [markdown]
# <b> <i> Before starting the lab, please run the following code in order to access the solutions </i> </b>

# %%
from IPython.core.display import HTML
HTML("""
<style type="text/css">
    #ans:hover { background-color: black; }
    #ans {padding: 6px; 
        background-color: white; 
        border: green 2px solid;
        font-weight: bold}
</style>
""")
# Out:
# <style type="text/css">
#     #ans:hover { background-color: black; }
#     #ans {padding: 6px;
#         background-color: white;
#         border: green 2px solid;
#         font-weight: bold}
# </style>

# %% [markdown]
# # <u>Random Forests with RandomForestClassifier</u>

# %% [markdown]
# Import the <b>RandomForestClassifier</b> class from <b>sklearn.ensemble</b>

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# from sklearn.ensemble import RandomForestClassifier
# </font> </p>

# %% [markdown]
# Create an instance of the <b>RandomForestClassifier()</b> called <b>skullsForest</b>, where the forest has <b>10 decision tree estimators</b> (<i>n_estimators=10</i>) and the <b>criterion is entropy</b> (<i>criterion="entropy"</i>)

# %%
skullsForest = RandomForestClassifier(n_estimators=10, criterion="entropy") 
my_data = pandas.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/HSAUR/skulls.csv", delimiter=",")

# %%
X = my_data.drop(my_data.columns[[0,1]], axis=1).values
print(X)
X[0:5]
print(X[0:5])
# Out:
# [[131 138  89  49]
#  [125 131  92  48]
#  [131 132  99  50]
#  [119 132  96  44]
#  [136 143 100  54]
#  [138 137  89  56]
#  [139 130 108  48]
#  [125 136  93  48]
#  [131 134 102  51]
#  [134 134  99  51]
#  [129 138  95  50]
#  [134 121  95  53]
#  [126 129 109  51]
#  [132 136 100  50]
#  [138 136  92  46]
#  [131 129  97  44]
#  [143 126  88  54]
#  [134 124  91  55]
#  [132 127  97  52]
#  [137 125  85  57]
#  [129 128  81  52]
#  [140 135 103  48]
#  [147 129  87  48]
#  [136 133  97  51]]
# [[131 138  89  49]
#  [125 131  92  48]
#  [131 132  99  50]
#  [119 132  96  44]
#  [136 143 100  54]]

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# skullsForest=RandomForestClassifier(n_estimators=10, criterion="entropy")
# </font> </p>

# %%
y = my_data["epoch"]

# %%
from sklearn.cross_validation import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %% [markdown]
# Let's use the same <b>X_trainset</b>, <b>y_trainset</b> datasets that we made when dealing with the <b>Decision Trees</b> above to fit <b>skullsForest</b>.
# <br> <br>
# <b>Note</b>: Make sure you have ran through the Decision Trees section.

# %%
skullsForest.fit(X_trainset,y_trainset)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# skullsForest.fit(X_trainset, y_trainset)
# </font> </p>

# %% [markdown]
# Let's now create a variable called <b>predForest</b> using a predict on <b>X_testset</b> with <b>skullsForest</b>.

# %%
predForest = skullsForest.predict(X_testset)

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# predForest = skullsForest.predict(X_testset)
# </font> </p>

# %% [markdown]
# You can print out <b>predForest</b> and <b>y_testset</b> if you want to visually compare the prediction to the actual values.

# %%
print(predForest)
print(y_testset)
# Out:
# ['c4000BC' 'c4000BC' 'c1850BC' 'cAD150' 'c200BC' 'c200BC' 'c1850BC'
#  'c3300BC' 'c3300BC' 'cAD150' 'cAD150' 'c4000BC' 'cAD150' 'cAD150'
#  'c1850BC' 'c200BC' 'cAD150' 'cAD150' 'c1850BC' 'c3300BC' 'c200BC'
#  'cAD150' 'c3300BC' 'c1850BC' 'c200BC' 'cAD150' 'cAD150' 'c4000BC'
#  'c1850BC' 'cAD150' 'c200BC' 'c3300BC' 'cAD150' 'c200BC' 'c4000BC'
#  'c3300BC' 'cAD150' 'c4000BC' 'cAD150' 'c1850BC' 'c200BC' 'c1850BC'
#  'cAD150' 'c200BC' 'c3300BC']
# 47     c3300BC
# 3      c4000BC
# 31     c3300BC
# 25     c4000BC
# 15     c4000BC
# 118     c200BC
# 89     c1850BC
# 6      c4000BC
# 103     c200BC
# 65     c1850BC
# 88     c1850BC
# 38     c3300BC
# 92      c200BC
# 53     c3300BC
# 140     cAD150
# 40     c3300BC
# 72     c1850BC
# 135     cAD150
# 113     c200BC
# 42     c3300BC
# 126     cAD150
# 112     c200BC
# 141     cAD150
# 76     c1850BC
# 5      c4000BC
# 109     c200BC
# 134     cAD150
# 67     c1850BC
# 57     c3300BC
# 86     c1850BC
# 14     c4000BC
# 24     c4000BC
# 139     cAD150
# 58     c3300BC
# 8      c4000BC
# 27     c4000BC
# 77     c1850BC
# 41     c3300BC
# 111     c200BC
# 68     c1850BC
# 128     cAD150
# 82     c1850BC
# 22     c4000BC
# 17     c4000BC
# 127     cAD150
# Name: epoch, dtype: object

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# print predForest <br>
# print y_testset
# </font> </p>

# %% [markdown]
# Let's check the accuracy of our model. <br>
#
# Note: Make sure you have metrics imported from sklearn

# %%
from sklearn import metrics

print("RandomForests's Accuracy: "), metrics.accuracy_score(y_testset, predForest)
# Out:
# RandomForests's Accuracy:
# (None, 0.24444444444444444)

# %% [markdown]
# We can also see what trees are in our <b> skullsForest </b> variable by using the <b> .estimators_ </b> attribute. This attribute is indexable, so we can look at any individual tree we want.

# %%
print(skullsForest.estimators_)
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=139823771, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=1645977781, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=1364488502, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=950622378, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=984896268, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=466290128, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=408674562, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=228449175, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=572981337, splitter='best'), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=499095875, splitter='best')]

# %% [markdown]
# Hover over the green box below for the answer
# <p id = "ans"> <font color = "white">
# print(skullsForest.estimators_)
# </font> </p>

# %% [markdown]
# You can choose to view any tree by using the code below. Replace the <i>"&"</i> in <b>skullsForest[&]</b> with the tree you want to see.

# %%
featureNames = list(my_data.columns.values)[2:6]
print(featureNames)
targetNames = my_data["epoch"].unique().tolist()
targetNames
# Out:
# ['mb', 'bh', 'bl', 'nh']
# ['c4000BC', 'c3300BC', 'c1850BC', 'c200BC', 'cAD150']

# %%
from IPython.display import Image  
import pydot
from sklearn import tree
from sklearn.externals.six import StringIO  
dot_data = StringIO()

#Replace the '&' below with the tree number
tree.export_graphviz(skullsForest[1], out_file=dot_data,
                     feature_names=featureNames,
                     class_names=targetNames,
                     filled=True, rounded=True,
                     special_characters=True,
                     leaves_parallel=True)
(graph, )  = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## Want to learn more?
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: [SPSS Modeler for Mac users](https://cocl.us/ML0101EN_SPSSMod_mac) and [SPSS Modeler for Windows users](https://cocl.us/ML0101EN_SPSSMod_win)
#
# Also, you can use Data Science Experience to run these notebooks faster with bigger datasets. Data Science Experience is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, DSX enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of DSX users today with a free account at [Data Science Experience](https://cocl.us/ML0101EN_DSX)

# %% [markdown]
# ---
# # Additional Resources
# <br>
# General Clustering: http://scikit-learn.org/stable/modules/clustering.html
# <br><br>
# Random Forests: https://www.youtube.com/watch?v=3kYujfDgmNk

# %% [markdown]
# <hr>
# Copyright &copy; 2016 [Big Data University](https://bigdatauniversity.com/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).​
